# %% [markdown]
# # Risk Analysis

# %% [markdown]
# ## Install Dependencies

# %%
# %%capture
# %pip install pandas==1.3.5
# %pip install numpy==1.21.6

# %% [markdown]
# ## Import Modules

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Mount Drive

# %%
import os

team_name = 'capstone-power-grid-protagonists'
colab_path = f'/content/drive/Shareddrives/{team_name}/project'
studiolab_path = f'/home/studio-lab-user/sagemaker-studiolab-notebooks/{team_name}'

try:
    # Try to mount Google Drive and set project path
    from google.colab import drive
    drive.flush_and_unmount()
    drive.mount('/content/drive')
    print('')

    root_path = colab_path
    os.chdir(root_path)

except:
    try:
        # Try to set AWS SageMaker Studio Lab project path
        root_path = studiolab_path
        os.chdir(root_path)
    
    except:
        # Set current working directory as root path
        root_path = os.getcwd()
        os.chdir(root_path)

        # If the current folder is 'notebooks', move up one level
        if root_path.endswith('/notebooks'):
            root_path = '/'.join(root_path.split('/')[:-1])
            os.chdir(root_path)
        
print('Current working directory is:')
print(os.getcwd())
# Out:
# Mounted at /content/drive
#
# Current working directory is:
# /content/drive/Shareddrives/capstone-power-grid-protagonists/project

# %% [markdown]
# ## Import Data

# %%
# Processed data
plants = pd.read_csv('data/processed/hifld/power_plants.csv', low_memory=False)
subs = pd.read_csv('data/processed/hifld/substations.csv', low_memory=False)
bas = pd.read_csv('data/processed/eia/balancing_authorities.csv', low_memory=False)

# %% [markdown]
# ## Analysis

# %%
# This function will return the dataframe with defined columns ranked and a final risk score
def risk_score(df,
               cols=['deg_cent', 'bet_cent', 'clust_coef', 'disturbance_prob', 'outage_prob', 'potential_population_affected'],
               ascending=[True, True, False, True, True, True]):

    rank_cols = []

    for idx, col in enumerate(cols):
        if col in df.columns.tolist():
            rank_col = col + '_rank'
            df[rank_col] = df[col].rank(na_option='bottom', pct=True, ascending=ascending[idx])
            rank_cols.append(rank_col)

    df['risk_score'] = df[rank_cols].mean(axis=1).round(3)
    
    return df.sort_values('risk_score', ascending=False)

# %%
plants = risk_score(plants)
subs = risk_score(subs)
bas = risk_score(bas)

# %%
subs[['sub_code', 'name', 'city', 'state', 'deg_cent', 'bet_cent', 'clust_coef', 'disturbance_prob', 'outage_prob', 'potential_population_affected', 'risk_score']].head(25)
# Out:
#        sub_code                name                    city state  deg_cent  \
# 35743    150577        Conservation         Fort Lauderdale    FL  0.000133
# 36533    151373        Florida City               Homestead    FL  0.000089
# 35875    150710           Princeton               Homestead    FL  0.000089
# 37083    151932        Oakland Park            Oakland Park    FL  0.000111
# 36117    150957        Miami Shores                   Miami    FL  0.000089
# 36080    150919             Moffett               Hollywood    FL  0.000089
# 36135    150975        Little River                   Miami    FL  0.000111
# 35770    150606        Country Club                 Hialeah    FL  0.000089
# 71745    308689       Unknown308689           West Columbia    TX  0.000133
# 36525    151365                Lucy               Homestead    FL  0.000111
# 37056    151905            Sistrunk         Fort Lauderdale    FL  0.000111
# 36638    151479          Cape North              Cape Coral    FL  0.000111
# 75067    300115      Cooley Landing          East Palo Alto    CA  0.000111
# 71730    308665       Unknown308665           West Columbia    TX  0.000111
# 8557     117706       Unknown117706                Wildwood    MO  0.000111
# 35058    149876              Jaguar             Baton Rouge    LA  0.000178
# 36247    151086            Ringling                Sarasota    FL  0.000111
# 35884    150719             Emerson             Fort Pierce    FL  0.000111
# 73568    300415       Unknown300415                Monterey    CA  0.000089
# 35031    149850            Harelson             Baton Rouge    LA  0.000200
# 74666    309336  Hillsdale Junction  Highlands-Baywood Park    CA  0.000089
# 31384    146106         Eerie South                    Erie    PA  0.000155
# 36699    151546         Black Creek                Callahan    FL  0.000178
# 35703    150538         South Miami                   Miami    FL  0.000089
# 35744    150578             Phoenix                 Tamarac    FL  0.000067
#
#        bet_cent  clust_coef  disturbance_prob  outage_prob  \
# 35743  0.000654         0.0          0.051957     0.044423
# 36533  0.000417         0.0          0.051957     0.044423
# 35875  0.000476         0.0          0.051957     0.044423
# 37083  0.000207         0.0          0.051957     0.044423
# 36117  0.000163         0.0          0.051957     0.044423
# 36080  0.000169         0.0          0.051957     0.044423
# 36135  0.000090         0.0          0.051957     0.044423
# 35770  0.000115         0.0          0.051957     0.044423
# 71745  0.000426         0.0          0.135421     0.096575
# 36525  0.000076         0.0          0.051957     0.044423
# 37056  0.000090         0.0          0.051957     0.044423
# 36638  0.000170         0.0          0.051957     0.044423
# 75067  0.000127         0.0          0.108023     0.069667
# 71730  0.000220         0.0          0.135421     0.096575
# 8557   0.007934         0.0          0.019863     0.014677
# 35058  0.000542         0.0          0.032387     0.025342
# 36247  0.000205         0.0          0.051957     0.044423
# 35884  0.000365         0.0          0.051957     0.044423
# 73568  0.000203         0.0          0.108023     0.069667
# 35031  0.000209         0.0          0.032387     0.025342
# 74666  0.000093         0.0          0.108023     0.069667
# 31384  0.000576         0.0          0.041879     0.034638
# 36699  0.000471         0.0          0.051957     0.044423
# 35703  0.000051         0.0          0.051957     0.044423
# 35744  0.000241         0.0          0.051957     0.044423
#
#        potential_population_affected  risk_score
# 35743                      1930983.0       0.890
# 36533                      2662777.0       0.884
# 35875                      2662777.0       0.884
# 37083                      1930983.0       0.879
# 36117                      2662777.0       0.875
# 36080                      1930983.0       0.871
# 36135                      2662777.0       0.868
# 35770                      2662777.0       0.868
# 71745                       379689.0       0.867
# 36525                      2662777.0       0.864
# 37056                      1930983.0       0.864
# 36638                       787976.0       0.862
# 75067                       737888.0       0.860
# 71730                       379689.0       0.859
# 8557                        997187.0       0.856
# 35058                       453301.0       0.855
# 36247                       447057.0       0.852
# 35884                       343579.0       0.851
# 73568                       437325.0       0.851
# 35031                       453301.0       0.848
# 74666                       737888.0       0.848
# 31384                       269011.0       0.847
# 36699                       222361.0       0.846
# 35703                      2662777.0       0.846
# 35744                      1930983.0       0.846

# %%
bas[['ba_code', 'ba_name', 'region_country_name', 'deg_cent', 'bet_cent', 'clust_coef', 'disturbance_prob', 'outage_prob', 'potential_population_affected', 'risk_score']].head(10)
# Out:
#    ba_code                                         ba_name  \
# 33    MISO  Midcontinent Independent System Operator, Inc.
# 40     PJM                        PJM Interconnection, LLC
# 8     CISO          California Independent System Operator
# 15    ERCO     Electric Reliability Council of Texas, Inc.
# 52    SWPP                            Southwest Power Pool
# 36    NYIS            New York Independent System Operator
# 29    ISNE                                 ISO New England
# 49    SOCO         Southern Company Services, Inc. - Trans
# 13     DUK                           Duke Energy Carolinas
# 6     BPAT                 Bonneville Power Administration
#
#    region_country_name  deg_cent  bet_cent  clust_coef  disturbance_prob  \
# 33             Midwest  0.167168  0.003064    0.000020          0.240998
# 40        Mid-Atlantic  0.136126  0.001431    0.000019          0.125049
# 8           California  0.108489  0.000812    0.000060          0.102544
# 15               Texas  0.037377  0.000315    0.000000          0.129941
# 52             Central  0.048385  0.002774    0.000172          0.054207
# 36            New York  0.056066  0.000722    0.000032          0.038845
# 29         New England  0.082040  0.000477    0.000015          0.044423
# 49           Southeast  0.025578  0.001069    0.000846          0.022211
# 13           Carolinas  0.040862  0.000402    0.000421          0.015949
# 6            Northwest  0.012987  0.000690    0.006293          0.034540
#
#     outage_prob  potential_population_affected  risk_score
# 33     0.185812                   6.789936e+08       0.901
# 40     0.083072                   9.622316e+08       0.890
# 8      0.067319                   2.125385e+09       0.874
# 15     0.093053                   1.562223e+09       0.865
# 52     0.035421                   1.497914e+08       0.847
# 36     0.025049                   3.455549e+08       0.845
# 29     0.028278                   2.595587e+08       0.845
# 49     0.018982                   2.067478e+08       0.813
# 13     0.011252                   2.547153e+08       0.780
# 6      0.016243                   2.152927e+08       0.773

# %%
subs.groupby('state')[['state', 'deg_cent', 'bet_cent', 'clust_coef', 'disturbance_prob', 'outage_prob', 'potential_population_affected', 'risk_score']].mean().sort_values(by='risk_score', ascending=False).head(10)
# Out:
#        deg_cent  bet_cent  clust_coef  disturbance_prob  outage_prob  \
# state
# MO     0.000049  0.000703    0.041660          0.015859     0.012461
# MA     0.000052  0.000191    0.036368          0.006428     0.005093
# NC     0.000049  0.000166    0.043363          0.011558     0.009683
# WA     0.000053  0.000113    0.024084          0.024055     0.014959
# NY     0.000046  0.000170    0.038890          0.021248     0.014586
# IL     0.000047  0.000534    0.035130          0.015045     0.013378
# CT     0.000052  0.000082    0.082908          0.005510     0.004599
# TX     0.000052  0.000225    0.036376          0.054766     0.042963
# TN     0.000054  0.000420    0.061742          0.010421     0.006900
# LA     0.000051  0.000334    0.034302          0.016551     0.013822
#
#        potential_population_affected  risk_score
# state
# MO                     144156.663763    0.566581
# MA                     761991.844479    0.562212
# NC                     232810.271938    0.559408
# WA                     526808.815094    0.556256
# NY                     426693.786691    0.546036
# IL                     613625.088942    0.544861
# CT                     654266.528053    0.537997
# TX                     743140.968804    0.537764
# TN                     193596.471259    0.535572
# LA                     153359.353455    0.522787

# %%
bas.groupby('region_country_name')[['region_country_name', 'deg_cent', 'bet_cent', 'clust_coef', 'disturbance_prob', 'outage_prob', 'potential_population_affected', 'risk_score']].mean().sort_values(by='risk_score', ascending=False).head(10)
# Out:
#                      deg_cent  bet_cent  clust_coef  disturbance_prob  \
# region_country_name
# Mid-Atlantic         0.136126  0.001431    0.000019          0.125049
# Texas                0.037377  0.000315    0.000000          0.129941
# New England          0.082040  0.000477    0.000015          0.044423
# New York             0.056066  0.000722    0.000032          0.038845
# Tennessee            0.011403  0.000274    0.003499          0.015949
# Central              0.025538  0.001393    0.010839          0.027104
# California           0.025467  0.000186    0.012565          0.021605
# Midwest              0.043435  0.000797    0.263847          0.061130
# Northwest            0.004853  0.000193    0.070187          0.008070
# Carolinas            0.014663  0.000120    0.060569          0.004941
#
#                      outage_prob  potential_population_affected  risk_score
# region_country_name
# Mid-Atlantic            0.083072                   9.622316e+08    0.890000
# Texas                   0.093053                   1.562223e+09    0.865000
# New England             0.028278                   2.595587e+08    0.845000
# New York                0.025049                   3.455549e+08    0.845000
# Tennessee               0.010665                   9.212301e+07    0.726000
# Central                 0.017710                   1.497914e+08    0.632000
# California              0.013933                   5.327044e+08    0.550000
# Midwest                 0.047040                   2.265024e+08    0.501000
# Northwest               0.003238                   3.506813e+07    0.497381
# Carolinas               0.002723                   6.460901e+07    0.495667
